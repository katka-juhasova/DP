# %%
import os
import cv2
import numpy as np
import random
import matplotlib.pyplot as plt 
import plotly.graph_objects as go

# %%
# '021_ReferenceRenderer_ReferenceZMap.tif', - referencia, tzv. recept, to je to co tam hladame
# '027_RenderTiltedLlt_RenderLlt.tif', - meranie
# '041_StraightenSidewall_foreground.tif', - meranie vyrovnane Jaccobiho iteracnym algoritmom
# '061_AutoFitting_autofitting.png', - referencia polozena na vyrovnane meranie (redukovana presnost z 65535 na 24000 stpcov, obsahuje aj chyby)
# '061_AutoFitting_globalOffset.txt', - detekovane posunutie merania voci receptu (v presnosti 24000 stlpcov)
# '061_AutoFitting_grey.png', (vizualizacia v 24000 stlpcoch)
# '061_AutoFitting_target.png', (priradene targety v 24000)
# '061_AutoFitting_template.png', (recept v 24000)
# '069_TsiliHierarchicAlignment_GlyphAlignmentNonRigid.png' (finalna registracia - obsahuje aj chyby)

# %%
dir = 'data/03/05/2020-03-05_17-32-03_144930_8503077770_MeasureTop'

reference = os.path.join(dir, '1_Sidewall_021_ReferenceRenderer_ReferenceZMap.tif')
meassure = os.path.join(dir, '1_Sidewall_027_RenderTiltedLlt_RenderLlt.tif')
meassure_flatten = os.path.join(dir, '1_Sidewall_041_StraightenSidewall_foreground.tif')
autofit = os.path.join(dir, '1_Sidewall_061_AutoFitting_autofitting.png')
offset = os.path.join(dir, '1_Sidewall_061_AutoFitting_globalOffset.txt')
autofit_grey = os.path.join(dir, '1_Sidewall_061_AutoFitting_grey.png')
autofit_targer = os.path.join(dir, '1_Sidewall_061_AutoFitting_target.png')
autofit_reference = os.path.join(dir, '1_Sidewall_061_AutoFitting_template.png')
registration = os.path.join(dir, '1_Sidewall_069_TsiliHierarchicAlignment_GlyphAlignmentNonRigid.png')

# %%
plt.figure(figsize=(20, 10))

img = plt.imread(autofit_grey)
# img = img[:, :, :-1]
img.shape
# Out:
# (1600, 24000)

# %%
rows, cols = img.shape
random.seed(7)

x = np.array(list(range(rows)) * cols)[:1000]
y = np.array(list(range(cols)) * rows)[:1000]
z = img.flatten()[:1000]

# %%
fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z, mode='markers')])
fig.show()
